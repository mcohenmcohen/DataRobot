# %% [markdown]
# ### Step 0: Specify configuration
# - project id, data file
# - configuration: which models to use
#
# ### Step 1: Download stacked predictions from DR
# (from models selected using specified heuristics)
#
# ### Step 2: Merge these Predictions together, along with the target and partitioning
#
# ### Step 3: Run non-negative least squares
# This is a constrained optimization problem where the coefficient must be positive or 0 (as the name implies).
#
# ### Step 4: Take the non-zero coefficients and build blenders
# I've seen this work well in my own research projects. Can be applied to both regression and classification projects (if applied to classification problems, target must be converted to an integer). The advantage of this is that it's fast and doesn't require making a new project. Ideally, the solution would automatically produce the right balance between diversity and accuracy. You could also just compute predictions using the calculated coefficients for each model directly (this approach is the default for the SuperLearner package https://www.rdocumentation.org/packages/SuperLearner/versions/2.0-24/topics/SuperLearner).

# %%
import datarobot as dr
import pandas as pd
import numpy as np
dr.__version__
# Out:
# '2.17.0'

# %%
# Which models do we use?
limit_to_already_cv_only = False  # only use models that already ran CV
limit_to_top_models = True  # limit to top X models
num_top_models = 30  # only use top 30 models

# %%
# https://datarobot.atlassian.net/wiki/spaces/CFDS/pages/558858298/Sports+Analytics+Predicting+NBA+Player+Performance+-+Regression

training_df = pd.read_csv("https://s3.amazonaws.com/datarobot_public_datasets/DR_Demo_NBA_2017-2018.csv")
training_df.sample(5)
# Out:
#       roto_fpts_per_min  roto_minutes  roto_fpts  roto_value  \
# 3810                NaN           NaN        NaN         NaN
# 479                1.01          27.0       27.3        5.15
# 2639               0.84          33.0       27.7        4.20
# 6291               0.87          31.0       26.9        5.07
# 1355                NaN           NaN        NaN         NaN
#
#       free_throws_lag30_mean  field_goals_decay1_mean  game_score_lag30_mean  \
# 3810                1.461538                 0.966304              11.230769
# 479                 0.866667                 3.591254               6.133333
# 2639                2.200000                 7.531135              12.820000
# 6291                0.933333                 1.718828               3.473333
# 1355                0.928571                 2.797223               5.264286
#
#       minutes_played_decay1_mean  PF_lastseason  \
# 3810                    7.509653            2.4
# 479                    26.921195            2.6
# 2639                   33.929150            1.6
# 6291                   25.055692            0.9
# 1355                   25.690895            2.3
#
#       free_throws_attempted_lag30_mean     ...      team  opponent  \
# 3810                          1.923077     ...       OKC       CHI
# 479                           1.400000     ...       MIA       PHI
# 2639                          2.866667     ...       DAL       CHI
# 6291                          1.133333     ...       SAS       PHI
# 1355                          1.428571     ...       BRK       IND
#
#       over_under  eff_field_goal_percent_lastseason  spread_decay1_mean  \
# 3810         NaN                              0.571            7.301062
# 479        201.0                              0.535            0.901175
# 2639       210.5                              0.498            0.530440
# 6291       206.5                              0.481            3.433701
# 1355         NaN                              0.543          -18.001993
#
#       position  OWS_lastseason free_throws_percent_decay1  \
# 3810         C             3.3                   0.788001
# 479         PF             1.9                   0.935095
# 2639        SF             2.5                   0.864345
# 6291        SF             0.7                   0.760559
# 1355        SG             0.1                   0.621636
#
#                                text_yesterday_and_today  game_score
# 3810  Thunder's Steven Adams: Doubtful for Wednesday...         0.0
# 479   Heat's James Johnson: Scores eight points in W...         2.9
# 2639                                                NaN        18.0
# 6291                                                NaN        10.5
# 1355                                                NaN         9.3
#
# [5 rows x 52 columns]

# %%
# Run autopilot

dr.Client(config_path="/Users/taylor.larkin/.config/datarobot/drconfig.yaml")

project = dr.Project.start(project_name="BBB NNLS NBA", sourcedata=training_df,
                           target="game_score", worker_count=-1)
project.wait_for_autopilot()
# Out:
# In progress: 4, queued: 32 (waited: 0s)
# In progress: 4, queued: 32 (waited: 1s)
# In progress: 4, queued: 32 (waited: 1s)
# In progress: 4, queued: 32 (waited: 2s)
# In progress: 6, queued: 30 (waited: 4s)
# In progress: 8, queued: 28 (waited: 6s)
# In progress: 8, queued: 28 (waited: 9s)
# In progress: 14, queued: 22 (waited: 17s)
# In progress: 17, queued: 19 (waited: 30s)
# In progress: 17, queued: 16 (waited: 51s)
# In progress: 12, queued: 16 (waited: 71s)
# In progress: 6, queued: 16 (waited: 92s)
# In progress: 8, queued: 11 (waited: 114s)
# In progress: 15, queued: 1 (waited: 134s)
# In progress: 16, queued: 0 (waited: 155s)
# In progress: 9, queued: 0 (waited: 175s)
# In progress: 6, queued: 0 (waited: 196s)
# In progress: 1, queued: 0 (waited: 216s)
# In progress: 3, queued: 14 (waited: 236s)
# In progress: 6, queued: 11 (waited: 257s)
# In progress: 14, queued: 2 (waited: 277s)
# In progress: 13, queued: 0 (waited: 303s)
# In progress: 8, queued: 0 (waited: 323s)
# In progress: 3, queued: 0 (waited: 344s)
# In progress: 3, queued: 0 (waited: 365s)
# In progress: 1, queued: 0 (waited: 385s)
# In progress: 1, queued: 0 (waited: 405s)
# In progress: 9, queued: 0 (waited: 426s)
# In progress: 9, queued: 0 (waited: 446s)
# In progress: 8, queued: 0 (waited: 466s)
# In progress: 7, queued: 0 (waited: 487s)
# In progress: 3, queued: 0 (waited: 507s)
# In progress: 2, queued: 0 (waited: 527s)
# In progress: 1, queued: 0 (waited: 547s)
# In progress: 1, queued: 0 (waited: 568s)
# In progress: 1, queued: 0 (waited: 588s)
# In progress: 6, queued: 26 (waited: 608s)
# In progress: 10, queued: 22 (waited: 629s)
# In progress: 12, queued: 20 (waited: 649s)
# In progress: 18, queued: 10 (waited: 670s)
# In progress: 18, queued: 8 (waited: 690s)
# In progress: 12, queued: 6 (waited: 711s)
# In progress: 12, queued: 0 (waited: 736s)
# In progress: 7, queued: 0 (waited: 757s)
# In progress: 4, queued: 0 (waited: 777s)
# In progress: 2, queued: 0 (waited: 797s)
# In progress: 1, queued: 0 (waited: 818s)
# In progress: 0, queued: 0 (waited: 838s)
# In progress: 0, queued: 0 (waited: 859s)
# In progress: 5, queued: 0 (waited: 879s)
# In progress: 5, queued: 0 (waited: 899s)
# In progress: 5, queued: 0 (waited: 919s)
# In progress: 4, queued: 0 (waited: 945s)
# In progress: 1, queued: 0 (waited: 965s)
# In progress: 1, queued: 0 (waited: 991s)
# In progress: 1, queued: 0 (waited: 1012s)
# In progress: 1, queued: 0 (waited: 1033s)
# In progress: 1, queued: 0 (waited: 1054s)
# In progress: 1, queued: 0 (waited: 1079s)
# In progress: 1, queued: 0 (waited: 1099s)
# In progress: 2, queued: 0 (waited: 1120s)
# In progress: 2, queued: 0 (waited: 1140s)
# In progress: 2, queued: 0 (waited: 1160s)
# In progress: 1, queued: 0 (waited: 1180s)
# In progress: 1, queued: 0 (waited: 1201s)
# In progress: 1, queued: 0 (waited: 1221s)
# In progress: 1, queued: 0 (waited: 1241s)
# In progress: 1, queued: 0 (waited: 1262s)
# In progress: 1, queued: 0 (waited: 1283s)
# In progress: 1, queued: 0 (waited: 1304s)
# In progress: 4, queued: 0 (waited: 1324s)
# In progress: 4, queued: 0 (waited: 1349s)
# In progress: 4, queued: 0 (waited: 1370s)
# In progress: 4, queued: 0 (waited: 1390s)
# In progress: 4, queued: 0 (waited: 1410s)
# In progress: 4, queued: 0 (waited: 1430s)
# In progress: 2, queued: 0 (waited: 1451s)
# In progress: 2, queued: 0 (waited: 1471s)
# In progress: 2, queued: 0 (waited: 1491s)
# In progress: 0, queued: 0 (waited: 1511s)
# In progress: 0, queued: 0 (waited: 1532s)
# In progress: 0, queued: 0 (waited: 1552s)
# In progress: 0, queued: 0 (waited: 1577s)

# %%
print("Project Optimization Metric: " + project.metric)
print("Project Target: " + project.target)
total_rows = training_df.shape[0]
print(f'Total Training Rows: {total_rows}')
# Out:
# Project Optimization Metric: RMSE
# Project Target: game_score
# Total Training Rows: 9999

# %%
# assemble scoring data and attributes
# order by cv score, then by validation score

model_scores = pd.DataFrame(
    [[model.metrics[project.metric]['crossValidation'],
      model.metrics[project.metric]['validation'],
      model,
      model.training_row_count,
      model.model_category] for model in project.get_models(with_metric=project.metric)],
    columns=['cv', 'v', 'model', 'rows', 'category']).sort_values(['cv', 'v'],
                                                                 na_position='last')
# TODO: add ability to detect need for reverse sorting for metrics like AUC
model_scores
# Out:
#           cv         v                                              model  \
# 0   6.702872   6.66194                      Model('ExtraTrees Regressor')
# 4   6.726294   6.67778                              Model('ENET Blender')
# 3   6.726992   6.67760                               Model('AVG Blender')
# 2   6.727492   6.67451                      Model('Advanced AVG Blender')
# 1   6.729854   6.66923                              Model('ENET Blender')
# 5   6.731212   6.69450                      Model('ExtraTrees Regressor')
# 10  6.771144   6.71953                      Model('ExtraTrees Regressor')
# 6   6.775368   6.71667  Model('eXtreme Gradient Boosted Trees Regresso...
# 8   6.778788   6.71789  Model('eXtreme Gradient Boosted Trees Regresso...
# 11  6.783520   6.73290  Model('eXtreme Gradient Boosted Trees Regresso...
# 7   6.789884   6.71680  Model('Gradient Boosted Trees Regressor with E...
# 9   6.802258   6.71834             Model('Nystroem Kernel SVM Regressor')
# 12  6.814554   6.75687  Model('Gradient Boosted Trees Regressor (Least...
# 16  6.859706   6.79357          Model('Gradient Boosted Trees Regressor')
# 62  7.613706   7.49204  Model('Auto-Tuned Word N-Gram Text Modeler usi...
# 13       NaN   6.78621                      Model('ExtraTrees Regressor')
# 14       NaN   6.78626  Model('eXtreme Gradient Boosted Trees Regresso...
# 15       NaN   6.79031  Model('eXtreme Gradient Boosted Trees Regresso...
# 17       NaN   6.81384             Model('Nystroem Kernel SVM Regressor')
# 18       NaN   6.82028             Model('Nystroem Kernel SVM Regressor')
# 19       NaN   6.82135  Model('Gradient Boosted Trees Regressor with E...
# 20       NaN   6.82470  Model('Gradient Boosted Trees Regressor (Least...
# 21       NaN   6.82617  Model('eXtreme Gradient Boosted Trees Regresso...
# 22       NaN   6.83074          Model('Gradient Boosted Trees Regressor')
# 23       NaN   6.83531          Model('Gradient Boosted Trees Regressor')
# 24       NaN   6.83882  Model('Gradient Boosted Trees Regressor (Least...
# 25       NaN   6.83918                    Model('RandomForest Regressor')
# 26       NaN   6.84227               Model('Generalized Additive2 Model')
# 27       NaN   6.84367                    Model('RandomForest Regressor')
# 28       NaN   6.85167  Model('Gradient Boosted Greedy Trees Regressor...
# ..       ...       ...                                                ...
# 38       NaN   6.86677                           Model('Ridge Regressor')
# 39       NaN   6.86700                           Model('Ridge Regressor')
# 40       NaN   6.86782  Model('Gradient Boosted Trees Regressor with E...
# 41       NaN   6.86864  Model('eXtreme Gradient Boosted Trees Regresso...
# 42       NaN   6.86874                           Model('Ridge Regressor')
# 43       NaN   6.87060                           Model('Ridge Regressor')
# 44       NaN   6.87155  Model('Elastic-Net Regressor (mixing alpha=0.5...
# 45       NaN   6.88252  Model('Gradient Boosted Greedy Trees Regressor...
# 46       NaN   6.88663                    Model('RandomForest Regressor')
# 47       NaN   6.90190  Model('Auto-tuned K-Nearest Neighbors Regresso...
# 48       NaN   6.93338                    Model('RandomForest Regressor')
# 49       NaN   6.94732  Model('Light Gradient Boosted Trees Regressor ...
# 50       NaN   6.94907                           Model('Ridge Regressor')
# 51       NaN   6.96222  Model('eXtreme Gradient Boosted Trees Regresso...
# 52       NaN   6.97094  Model('Breiman and Cutler Random Forest Regres...
# 53       NaN   6.98153  Model('Auto-tuned K-Nearest Neighbors Regresso...
# 54       NaN   6.98277                           Model('Ridge Regressor')
# 55       NaN   7.07139  Model('Ridge Regressor with Binned numeric fea...
# 56       NaN   7.08389  Model('Eureqa Generalized Additive Model (3000...
# 57       NaN   7.08487                         Model('RuleFit Regressor')
# 58       NaN   7.13767                         Model('Linear Regression')
# 59       NaN   7.15359       Model('TensorFlow Neural Network Regressor')
# 60       NaN   7.25216                   Model('Decision Tree Regressor')
# 61       NaN   7.38218                   Model('Vowpal Wabbit Regressor')
# 63       NaN   7.50801  Model('Auto-Tuned Word N-Gram Text Modeler usi...
# 64       NaN   7.60146  Model('Auto-Tuned Word N-Gram Text Modeler usi...
# 65       NaN   7.66987                           Model('Ridge Regressor')
# 66       NaN   7.67349  Model('Auto-Tuned Word N-Gram Text Modeler usi...
# 67       NaN   8.03359                   Model('Mean Response Regressor')
# 68       NaN  13.34871        Model('Isolation Forest Anomaly Detection')
#
#     rows category
# 0   8000    model
# 4   6400    blend
# 3   6400    blend
# 2   6400    blend
# 1   6400    blend
# 5   6400    model
# 10  6400    model
# 6   6400    model
# 8   6400    model
# 11  6400    model
# 7   6400    model
# 9   6400    model
# 12  6400    model
# 16  6400    model
# 62  8000    model
# 13  3200    model
# 14  3200    model
# 15  3200    model
# 17  1600    model
# 18  3200    model
# 19  3200    model
# 20  3200    model
# 21  3200    model
# 22  1600    model
# 23  3200    model
# 24  1600    model
# 25  1600    model
# 26  3200    model
# 27  3200    model
# 28  3200    model
# ..   ...      ...
# 38  1600    model
# 39  3200    model
# 40  1600    model
# 41  1600    model
# 42  1600    model
# 43  3200    model
# 44  3200    model
# 45  1600    model
# 46  1600    model
# 47  1600    model
# 48  1600    model
# 49  1600    model
# 50  1600    model
# 51  1600    model
# 52  1600    model
# 53  1600    model
# 54  1600    model
# 55  1600    model
# 56  1600    model
# 57  1600    model
# 58  1600    model
# 59  1600    model
# 60  1600    model
# 61  1600    model
# 63  6400    model
# 64  3200    model
# 65  1600    model
# 66  1600    model
# 67  1600    model
# 68  1600    model
#
# [69 rows x 5 columns]

# %%
# Eliminate blenders, prime models, and scaleout models.
# Eliminate anything not at the max training percentage of the project
# If we are not training new CV models, eliminate the ones that haven't run CV yet.
# If we are limiting to top models, select the top X models from remaining ones,
#     otherwise select all of them.

if limit_to_already_cv_only:
    models_to_use = model_scores.loc[
        (model_scores['category'] == 'model')
        & (model_scores['rows'] == project.max_train_rows)
        & model_scores['cv'].notna(),
        'model'].tolist()
else:
    models_to_use = model_scores.loc[
        (model_scores['category'] == 'model')
        & (model_scores['rows'] == project.max_train_rows),
        'model'].tolist()
if limit_to_top_models:
    models_to_use = models_to_use[:num_top_models]
models_to_use
# Out:
# [Model('ExtraTrees Regressor'),
#  Model('ExtraTrees Regressor'),
#  Model('eXtreme Gradient Boosted Trees Regressor with Early Stopping'),
#  Model('eXtreme Gradient Boosted Trees Regressor with Early Stopping'),
#  Model('eXtreme Gradient Boosted Trees Regressor with Early Stopping and Unsupervised Learning Features'),
#  Model('Gradient Boosted Trees Regressor with Early Stopping (Least-Squares Loss)'),
#  Model('Nystroem Kernel SVM Regressor'),
#  Model('Gradient Boosted Trees Regressor (Least-Squares Loss)'),
#  Model('Gradient Boosted Trees Regressor'),
#  Model('Auto-Tuned Word N-Gram Text Modeler using token occurrences - text_yesterday_and_today')]

# %%
# kick off all training predictions jobs if they haven't already been run
train_pred_jobs = list()
for model in models_to_use:
    if not model.metrics[project.metric]['crossValidation']:  # if CV has not been run, try to run CV
        try:
            model.cross_validate()
            print('Cross Validation begun for model ' + model.id)
        except Exception as e:
            print('CV error: ', str(e))
    try:
        train_pred_jobs.append(model.request_training_predictions(dr.enums.DATA_SUBSET.ALL))
        print('Training Predictions begun for model ' + model.id)
    except Exception as e:
        if str(e) == "422 client error: {'message': 'Training predictions request already submitted for these parameters'}":
            print('Predictions already kicked off for model ' + model.id)
        else:
            print(str(e))
print('\nAll training prediction jobs kicked off')
# Out:
# Training Predictions begun for model 5d827f3495d0303a8079d17e
# Training Predictions begun for model 5d8280fb27f88e74fa044e34
# Training Predictions begun for model 5d827f3495d0303a8079d189
# Training Predictions begun for model 5d827f3495d0303a8079d182
# Training Predictions begun for model 5d827f3495d0303a8079d180
# Training Predictions begun for model 5d827f3495d0303a8079d186
# Training Predictions begun for model 5d827f3495d0303a8079d184
# Training Predictions begun for model 5d827f3495d0303a8079d187
# Training Predictions begun for model 5d827f3495d0303a8079d18a
# Cross Validation begun for model 5d827f3495d0303a8079d17d
# Training Predictions begun for model 5d827f3495d0303a8079d17d
#
# All training prediction jobs kicked off

# %%
model_ids = [model.id for model in models_to_use]
# create a mapping from model ids to names, which start with model id and end with model_type,
#   like "5d6edd3578132c4e72cd27df eXtreme Gradient Boosted Trees Classifier with Early Stopping - Forest (10x)"
# I set them in this order so that the model id would be copyable, since tooltips are not. I would prefer using
#   "M127 eXtreme Gradient Boosted Trees Classifier with Early Stopping - Forest (10x)" but the M### are not available
model_ids_to_names = {model.id: model.id + ' ' + model.model_type
                      for model in models_to_use}

# %%
for train_pred_job in train_pred_jobs:
    train_pred_job.get_result_when_complete()
print('All training prediction jobs complete!')
# Out:
# All training prediction jobs complete!

# %%
tp_list = dr.TrainingPredictions.list(project_id=project.id)
predictions = [(model_ids_to_names[tp.model_id], tp.get_all_as_dataframe())
               for tp in tp_list if tp.model_id in model_ids and tp.data_subset == 'all']
predictions
# Out:
# [('5d827f3495d0303a8079d18a Gradient Boosted Trees Regressor',
#         row_id partition_id  prediction
#   0          0      Holdout   13.161561
#   1          1      Holdout   10.716866
#   2          2      Holdout   13.691411
#   3          3          4.0   11.504570
#   4          4          3.0   12.963454
#   5          5      Holdout   13.077293
#   6          6      Holdout   14.000896
#   7          7          4.0   11.731391
#   8          8          0.0   13.350650
#   9          9          1.0   14.454387
#   10        10          4.0   13.748579
#   11        11      Holdout   13.465634
#   12        12          2.0   13.768457
#   13        13          3.0   12.730611
#   14        14      Holdout   13.892001
#   15        15          4.0   14.224886
#   16        16      Holdout   13.339055
#   17        17          4.0   12.773731
#   18        18      Holdout   13.617614
#   19        19      Holdout   13.317456
#   20        20          2.0   13.762582
#   21        21          3.0    9.858629
#   22        22          3.0   14.067184
#   23        23          3.0   13.364315
#   24        24          3.0   12.636928
#   25        25          1.0   14.878590
#   26        26      Holdout   13.519995
#   27        27          2.0   10.556727
#   28        28          0.0    1.312286
#   29        29          2.0    2.667492
#   ...      ...          ...         ...
#   9969    9969          4.0   11.784777
#   9970    9970      Holdout   11.760451
#   9971    9971          4.0   12.025829
#   9972    9972      Holdout   12.964590
#   9973    9973          4.0   11.281804
#   9974    9974          1.0   10.949356
#   9975    9975          2.0   10.090482
#   9976    9976          4.0   11.021449
#   9977    9977          4.0   11.416842
#   9978    9978          4.0   12.058578
#   9979    9979          2.0   12.058578
#   9980    9980          0.0   13.770377
#   9981    9981          3.0   12.621190
#   9982    9982          2.0   14.587381
#   9983    9983          1.0   11.860778
#   9984    9984          0.0   11.882181
#   9985    9985          2.0   10.711962
#   9986    9986          2.0   11.860778
#   9987    9987      Holdout   10.978856
#   9988    9988          2.0   13.165964
#   9989    9989          0.0   13.624114
#   9990    9990          4.0   15.392393
#   9991    9991          3.0   13.363245
#   9992    9992          3.0   14.047645
#   9993    9993          1.0   13.456858
#   9994    9994      Holdout    9.263266
#   9995    9995          4.0   11.853259
#   9996    9996          2.0   13.560649
#   9997    9997          2.0   13.523004
#   9998    9998          4.0    8.794406
#
#   [9999 rows x 3 columns]),
#  ('5d827f3495d0303a8079
#   9985    9985          2.0   10.555685
#   9986    9986          2.0   10.555685
#   9987    9987      Holdout   11.341773
#   9988    9988          2.0   12.557619
#   9989    9989          0.0   12.604585
#   9990    9990          4.0   11.489802
#   9991    9991          3.0   10.760581
#   9992    9992          3.0   10.760581
#   9993    9993          1.0   11.103183
#   9994    9994      Holdout    9.991754
#   9995    9995          4.0   10.064702
#   9996    9996          2.0   12.578835
#   9997    9997          2.0   12.870942
#   9998    9998          4.0    8.424539
#
#   [9999 rows x 3 columns]),
#  ('5d8280fb27f88e74fa044e34 ExtraTrees Regressor',
#         row_id partition_id  prediction
#   0          0      Holdout   10.071771
#   1          1      Holdout   11.444714
#   2          2      Holdout   14.381510
#   3          3          4.0   12.554135
#   4          4          3.0   14.683216
#   5          5      Holdout   13.760434
#   6          6      Holdout   14.960875
#   7          7          4.0   15.453476
#   8          8          0.0   13.376334
#   9          9          1.0   15.290266
#   10        10          4.0   13.389043
#   11        11      Holdout   13.745251
#   12        12          2.0   13.347364
#   13        13          3.0   12.834633
#   14        14      Holdout   12.924244
#   15        15          4.0   14.459692
#   16        16      Holdout   14.036674
#   17        17          4.0   15.101102
#   18        18      Holdout   12.594042
#   19        19      Holdout   12.422085
#   20        20          2.0   12.687011
#   21        21          3.0    9.214040
#   22        22          3.0   14.825211
#   23        23          3.0   12.701153
#   24        24          3.0   12.922516
#   25        25          1.0   13.667085
#   26        26      Holdout    8.850617
#   27        27          2.0   12.279573
#   28        28          0.0    3.038705
#   29        29          2.0    4.208420
#   ...      ...          ...         ...
#   9969    9969          4.0   11.583836
#   9970    9970      Holdout   12.510211
#   9971    9971          4.0   12.161648
#   9972    9972      Holdout   11.430895
#   9973    9973          4.0   12.156642
#   9974    9974          1.0   12.082535
#   9975    9975          2.0   12.806250
#   9976    9976          4.0   10.883439
#   9977    9977          4.0   12.109082
#   9978    9978          4.0   12.194193
#   9979    9979          2.0   12.288565
#   9980    9980          0.0   15.688588
#   9981    9981          3.0   12.857568
#   9982    9982          2.0   11.216362
#   9983    9983          1.0    8.460041
#   9984    9984          0.0    6.699725
#   9985    9985          2.0   10.866849
#   9986    9986          2.0   10.866849
#   9987    9987      Holdout   12.365096
#   9988    9988          2.0   12.957652
#   9989    9989          0.0   12.873489
#   9990    9990          4.0   12.333153
#   9991    9991          3.0   12.210196
#   9992    9992          3.0   12.210196
#   9993    9993          1.0   11.807111
#   9994    9994      Holdout    9.881040
#   9995    9995          4.0   11.344661
#   9996    9996          2.0   12.556451
#   9997    9997          2.0   14.152015
#   9998    9998          4.0    8.945179
#
#   [9999 rows x 3 columns])]

# %%
pred_df = pd.DataFrame()
for model, tp_df in predictions:
    tp_df['Model'] = model
    pred_df = pred_df.append(tp_df, sort=True)

# %%
# quick sanity check to make sure partitions are consistent
all(pred_df.groupby(['partition_id', 'row_id']).agg({'Model': 'count'}).reset_index()['Model'] == 14)
# Out:
# False

# %%
# merge all the predictions...
merged_df = pd.DataFrame()
merged_df['target'] = training_df[project.target]
first = True
for model, tp_df in predictions:
    if first:
        merged_df['partition_id'] = tp_df['partition_id']
        first = False
    if project.target_type != "Regression":
        # Grab first class probabilities
        merged_df[model] = tp_df.iloc[:,3]
    else:
        # Grab predictions
        merged_df[model] = tp_df.iloc[:,2]   
    print(model + ' predictions downloaded')
merged_df
# Out:
# 5d827f3495d0303a8079d18a Gradient Boosted Trees Regressor predictions downloaded
# 5d827f3495d0303a8079d189 eXtreme Gradient Boosted Trees Regressor with Early Stopping predictions downloaded
# 5d827f3495d0303a8079d186 Gradient Boosted Trees Regressor with Early Stopping (Least-Squares Loss) predictions downloaded
# 5d827f3495d0303a8079d180 eXtreme Gradient Boosted Trees Regressor with Early Stopping and Unsupervised Learning Features predictions downloaded
# 5d827f3495d0303a8079d17d Auto-Tuned Word N-Gram Text Modeler using token occurrences - text_yesterday_and_today predictions downloaded
# 5d827f3495d0303a8079d187 Gradient Boosted Trees Regressor (Least-Squares Loss) predictions downloaded
# 5d827f3495d0303a8079d182 eXtreme Gradient Boosted Trees Regressor with Early Stopping predictions downloaded
# 5d827f3495d0303a8079d17e ExtraTrees Regressor predictions downloaded
# 5d827f3495d0303a8079d184 Nystroem Kernel SVM Regressor predictions downloaded
# 5d8280fb27f88e74fa044e34 ExtraTrees Regressor predictions downloaded
#       target partition_id  \
# 0        8.1      Holdout
# 1       18.6      Holdout
# 2        5.4      Holdout
# 3       16.5          4.0
# 4        8.4          3.0
# 5       25.5      Holdout
# 6       20.7      Holdout
# 7       18.3          4.0
# 8       23.0          0.0
# 9        0.4          1.0
# 10       7.2          4.0
# 11      21.6      Holdout
# 12       5.7          2.0
# 13      26.3          3.0
# 14      20.7      Holdout
# 15       9.8          4.0
# 16      16.6      Holdout
# 17      10.6          4.0
# 18      11.3      Holdout
# 19       1.7      Holdout
# 20       0.0          2.0
# 21      24.0          3.0
# 22      13.2          3.0
# 23      23.8          3.0
# 24      33.6          3.0
# 25      16.5          1.0
# 26       0.0      Holdout
# 27       0.0          2.0
# 28       0.0          0.0
# 29       0.0          2.0
# ...      ...          ...
# 9969    17.2          4.0
# 9970     3.3      Holdout
# 9971    11.6          4.0
# 9972    19.2      Holdout
# 9973    17.0          4.0
# 9974    15.6          1.0
# 9975     2.5          2.0
# 9976    17.3          4.0
# 9977    18.9          4.0
# 9978     7.1          4.0
# 9979     7.1          2.0
# 9980    25.0          0.0
# 9981    25.0          3.0
# 9982     9.2          2.0
# 9983    -1.2          1.0
# 9984    -1.2          0.0
# 9985    -1.2          2.0
# 9986    -1.2          2.0
# 9987    19.8      Holdout
# 9988    14.2          2.0
# 9989    15.7          0.0
# 9990    15.7          4.0
# 9991    15.7          3.0
# 9992    15.7          3.0
# 9993     0.0          1.0
# 9994     9.5      Holdout
# 9995    22.6          4.0
# 9996    14.3          2.0
# 9997     0.0          2.0
# 9998     0.0          4.0
#
#       5d827f3495d0303a8079d18a Gradient Boosted Trees Regressor  \
# 0                                             13.161561
# 1                                             10.716866
# 2                                             13.691411
# 3                                             11.504570
# 4                                             12.963454
# 5                                             13.077293
# 6                                             14.000896
# 7                                             11.731391
# 8                                             13.350650
# 9                                             14.454387
# 10                                            13.748579
# 11                                            13.465634
# 12                                            13.768457
# 13                                            12.730611
# 14                                            13.892001
# 9981                                          10.244167
# 9982                                          10.882688
# 9983                                           7.940510
# 9984                                           8.524707
# 9985                                          10.555685
# 9986                                          10.555685
# 9987                                          11.341773
# 9988                                          12.557619
# 9989                                          12.604585
# 9990                                          11.489802
# 9991                                          10.760581
# 9992                                          10.760581
# 9993                                          11.103183
# 9994                                           9.991754
# 9995                                          10.064702
# 9996                                          12.578835
# 9997                                          12.870942
# 9998                                           8.424539
#
#       5d8280fb27f88e74fa044e34 ExtraTrees Regressor
# 0                                         10.071771
# 1                                         11.444714
# 2                                         14.381510
# 3                                         12.554135
# 4                                         14.683216
# 5                                         13.760434
# 6                                         14.960875
# 7                                         15.453476
# 8                                         13.376334
# 9                                         15.290266
# 10                                        13.389043
# 11                                        13.745251
# 12                                        13.347364
# 13                                        12.834633
# 14                                        12.924244
# 15                                        14.459692
# 16                                        14.036674
# 17                                        15.101102
# 18                                        12.594042
# 19                                        12.422085
# 20                                        12.687011
# 21                                         9.214040
# 22                                        14.825211
# 23                                        12.701153
# 24                                        12.922516
# 25                                        13.667085
# 26                                         8.850617
# 27                                        12.279573
# 28                                         3.038705
# 29                                         4.208420
# ...                                             ...
# 9969                                      11.583836
# 9970                                      12.510211
# 9971                                      12.161648
# 9972                                      11.430895
# 9973                                      12.156642
# 9974                                      12.082535
# 9975                                      12.806250
# 9976                                      10.883439
# 9977                                      12.109082
# 9978                                      12.194193
# 9979                                      12.288565
# 9980                                      15.688588
# 9981                                      12.857568
# 9982                                      11.216362
# 9983                                       8.460041
# 9984                                       6.699725
# 9985                                      10.866849
# 9986                                      10.866849
# 9987                                      12.365096
# 9988                                      12.957652
# 9989                                      12.873489
# 9990                                      12.333153
# 9991                                      12.210196
# 9992                                      12.210196
# 9993                                      11.807111
# 9994                                       9.881040
# 9995                                      11.344661
# 9996                                      12.556451
# 9997                                      14.152015
# 9998                                       8.945179
#
# [9999 rows x 12 columns]

# %%
# Prepping data for non-negative least squares

y = merged_df.pop("target")

# In case of a classification problem
if project.target_type != "Regression":
    y = y.astype("category").cat.codes

X = merged_df.drop("partition_id", axis = 1)

# %%
# Perform non-negative least squares to select features

from scipy.optimize import nnls

nnls_opt = nnls(A=X.values, b=y)

# Selected models
selected_models = list(X.columns[np.nonzero(nnls_opt[0])])
selected_models
# Out:
# ['5d827f3495d0303a8079d189 eXtreme Gradient Boosted Trees Regressor with Early Stopping',
#  '5d827f3495d0303a8079d186 Gradient Boosted Trees Regressor with Early Stopping (Least-Squares Loss)',
#  '5d827f3495d0303a8079d180 eXtreme Gradient Boosted Trees Regressor with Early Stopping and Unsupervised Learning Features',
#  '5d827f3495d0303a8079d17e ExtraTrees Regressor',
#  '5d827f3495d0303a8079d184 Nystroem Kernel SVM Regressor']

# %%
# Make some blends

# Grab ids
model_ids_to_blend = [x.split(" ", 1)[0] for x in selected_models]

# Start blending
project.blend(model_ids_to_blend, dr.enums.BLENDER_METHOD.AVERAGE)
project.blend(model_ids_to_blend, dr.enums.BLENDER_METHOD.MEDIAN)
project.blend(model_ids_to_blend, dr.enums.BLENDER_METHOD.ENET)
project.blend(model_ids_to_blend, dr.enums.BLENDER_METHOD.GLM)
project.blend(model_ids_to_blend, dr.enums.BLENDER_METHOD.PLS)
project.blend(model_ids_to_blend, dr.enums.BLENDER_METHOD.TENSORFLOW)
# Out:
# ModelJob(TF Blender, status=inprogress)

# %%
project.open_leaderboard_browser()
# Out:
# True
