# %%
import sys
# sys.path.insert(0, '/Users/matthew.cohen/Dev/DataRobot-my\ github\ repo/David\ Shinn')

import find_optimal_thresholds_from_roc_curves as fo
import pandas as pd
import datarobot as dr

from pprint import pprint as pprint

# %%
#
# The non-functional programming version of David Shinn's code
# 
project = dr.Project.get('5c706f7f114a6d305a75e34c')

def find_optimal_threshold(tn, fn, tp, fp, model, source, objective_label='objective', maximize=True):

    def payoff_function(roc_point):
        tns = roc_point['true_negative_score']
        fns = roc_point['false_negative_score']
        tps = roc_point['true_positive_score']
        fps = roc_point['false_positive_score']
        return tn*tns + fn*fns + tp*tps + fp*fps

    # dict to return, holds all values we want to see/output
    output_values = {'project_id': model.project_id,  
                     'model_id': model.id,
                     'model_name': model.model_type,
                     objective_label: None}
    
    # Get the roc points for the source partition we want:
    # - validation', 'crossValidation', or 'holdout'
    for roc_curve in model.get_all_roc_curves():
        if roc_curve.source == source:
            break
    else: # source not found
        print('source not found:', output_values)
        return output_values

    # initialize the current best value to the first roc point
    best_index = 0
    best_value = payoff_function(roc_curve.roc_points[0])

    # update best_value as the cost value improves
    for current_index, roc_point in enumerate(roc_curve.roc_points[1:], 1):
        current_value = payoff_function(roc_point)
        if maximize:
            if current_value > best_value:
                best_value = current_value
                best_index = current_index
        else:
            if current_value < best_value:
                best_value = current_value
                best_index = current_index
    output_values.update(roc_curve.roc_points[best_index])
    output_values[objective_label] = best_value
    return output_values

model = project.get_models()[0]
objective_label = '_best_value'
source = 'crossValidation'  

# Lending Club example, where TN is worth 10 of interest and a FN is worth -100 of principal lost. 
# TP and FP have no effect since we’re not capturing opportunity costs.
find_optimal_threshold(tn=10, fn=-100, tp=0, fp=0,
                       model=model, source=source, objective_label=objective_label, maximize=True)
# Out:
# {'_best_value': 12820,
#  'accuracy': 0.45625,
#  'f1_score': 0.2899118511263467,
#  'false_negative_score': 148,
#  'false_positive_rate': 0.6033888569787479,
#  'false_positive_score': 4202,
#  'fraction_predicted_as_negative': 0.36375,
#  'fraction_predicted_as_positive': 0.63625,
#  'lift_negative': 1.0903399120859165,
#  'lift_positive': 1.34717934325007,
#  'matthews_correlation_coefficient': 0.1770992697535978,
#  'model_id': '5c70713ecaf9721bbf6ebe9c',
#  'model_name': 'Gradient Boosted Trees Classifier with Early Stopping',
#  'negative_predictive_value': 0.9491408934707903,
#  'positive_predictive_value': 0.17445972495088408,
#  'project_id': '5c706f7f114a6d305a75e34c',
#  'threshold': 0.08811994579510264,
#  'true_negative_rate': 0.39661114302125217,
#  'true_negative_score': 2762,
#  'true_positive_rate': 0.8571428571428571,
#  'true_positive_score': 888}

# %%
# 
# David's single model cost matrix optimize
# 
threshold = fo.find_optimal_threshold(model=project.get_models()[0],
                                        objective_function=fo.create_payoff_function(tn=10, fn=-100, tp=0, fp=0), 
                                        objective_label='payoff', source='crossValidation', maximize=True)
threshold
# Out:
# {'accuracy': 0.45625,
#  'f1_score': 0.2899118511263467,
#  'false_negative_score': 148,
#  'false_positive_rate': 0.6033888569787479,
#  'false_positive_score': 4202,
#  'fraction_predicted_as_negative': 0.36375,
#  'fraction_predicted_as_positive': 0.63625,
#  'lift_negative': 1.0903399120859165,
#  'lift_positive': 1.34717934325007,
#  'matthews_correlation_coefficient': 0.1770992697535978,
#  'model_id': '5c70713ecaf9721bbf6ebe9c',
#  'negative_predictive_value': 0.9491408934707903,
#  'payoff': 12820,
#  'positive_predictive_value': 0.17445972495088408,
#  'project_id': '5c706f7f114a6d305a75e34c',
#  'threshold': 0.08811994579510264,
#  'true_negative_rate': 0.39661114302125217,
#  'true_negative_score': 2762,
#  'true_positive_rate': 0.8571428571428571,
#  'true_positive_score': 888}

# %%
# 
# David's all models cost matrix optimize
# 
thresholds = fo.find_optimal_thresholds(project=project, 
                                        objective_function=fo.create_payoff_function(tn=10, fn=-100, tp=0, fp=0), 
                                        objective_label='payoff', source='crossValidation', maximize=True)
thresholds
# Out:
# [{'accuracy': 0.45625,
#   'f1_score': 0.2899118511263467,
#   'false_negative_score': 148,
#   'false_positive_rate': 0.6033888569787479,
#   'false_positive_score': 4202,
#   'fraction_predicted_as_negative': 0.36375,
#   'fraction_predicted_as_positive': 0.63625,
#   'lift_negative': 1.0903399120859165,
#   'lift_positive': 1.34717934325007,
#   'matthews_correlation_coefficient': 0.1770992697535978,
#   'model_id': '5c70713ecaf9721bbf6ebe9c',
#   'negative_predictive_value': 0.9491408934707903,
#   'payoff': 12820,
#   'positive_predictive_value': 0.17445972495088408,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.08811994579510264,
#   'true_negative_rate': 0.39661114302125217,
#   'true_negative_score': 2762,
#   'true_positive_rate': 0.8571428571428571,
#   'true_positive_score': 888},
#  {'accuracy': 0.496625,
#   'f1_score': 0.2961020800559343,
#   'false_negative_score': 189,
#   'false_positive_rate': 0.5511200459506032,
#   'false_positive_score': 3838,
#   'fraction_predicted_as_negative': 0.41437500000000005,
#   'fraction_predicted_as_positive': 0.585625,
#   'lift_negative': 1.0832698740256939,
#   'lift_positive': 1.3960598805849607,
#   'matthews_correlation_coefficient': 0.18160356924614954,
#   'model_id': '5c70736fcaf97227726ebe9a',
#   'negative_predictive_value': 0.9429864253393665,
#   'payoff': 12360,
#   'positive_predictive_value': 0.1807897545357524,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.09548582317457652,
#   'true_negative_rate': 0.4488799540493969,
#   'true_negative_score': 3126,
#   'true_positive_rate': 0.8175675675675675,
#   'true_positive_score': 847},
#  {'accuracy': 0.496875,
#   'f1_score': 0.2964516692885859,
#   'false_negative_score': 188,
#   'false_positive_rate': 0.5509764503159104,
#   'false_positive_score': 3837,
#   'fraction_predicted_as_negative': 0.41437500000000005,
#   'fraction_predicted_as_positive': 0.585625,
#   'lift_negative': 1.0836164094940322,
#   'lift_positive': 1.3977081212940339,
#   'matthews_correlation_coefficient': 0.18235932970162005,
#   'model_id': '5c70736fcaf97227726ebea0',
#   'negative_predictive_value': 0.943288084464555,
#   'payoff': 12470,
#   'positive_predictive_value': 0.1810032017075774,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.09555231037497083,
#   'true_negative_rate': 0.4490235496840896,
#   'true_negative_score': 3127,
#   'true_positive_rate': 0.8185328185328186,
#   'true_positive_score': 848},
#  {'accuracy': 0.5315,
#   'f1_score': 0.3056687662097073,
#   'false_negative_score': 211,
#   'false_positive_rate': 0.5078977599080988,
#   'false_positive_score': 3537,
#   'fraction_predicted_as_negative': 0.45475,
#   'fraction_predicted_as_positive': 0.54525,
#   'lift_negative': 1.08213796611743,
#   'lift_positive': 1.460489768605312,
#   'matthews_correlation_coefficient': 0.1944831432570088,
#   'model_id': '5c70736fcaf97227726ebe9e',
#   'negative_predictive_value': 0.9420010995052226,
#   'payoff': 13170,
#   'positive_predictive_value': 0.1891334250343879,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10293251995923602,
#   'true_negative_rate': 0.49210224009190123,
#   'true_negative_score': 3427,
#   'true_positive_rate': 0.7963320463320464,
#   'true_positive_score': 825},
#  {'accuracy': 0.496625,
#   'f1_score': 0.2963480691944784,
#   'false_negative_score': 188,
#   'false_positive_rate': 0.5512636415852958,
#   'false_positive_score': 3839,
#   'fraction_predicted_as_negative': 0.41412499999999997,
#   'fraction_predicted_as_positive': 0.585875,
#   'lift_negative': 1.0835770803856426,
#   'lift_positive': 1.3971117022109127,
#   'matthews_correlation_coefficient': 0.18217968234070664,
#   'model_id': '5c70736fcaf97227726ebe9c',
#   'negative_predictive_value': 0.9432538484757018,
#   'payoff': 12450,
#   'positive_predictive_value': 0.1809259654363132,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.0970273101391621,
#   'true_negative_rate': 0.4487363584147042,
#   'true_negative_score': 3125,
#   'true_positive_rate': 0.8185328185328186,
#   'true_positive_score': 848},
#  {'accuracy': 0.498,
#   'f1_score': 0.29814750087382036,
#   'false_negative_score': 183,
#   'false_positive_rate': 0.5504020677771396,
#   'false_positive_score': 3833,
#   'fraction_predicted_as_negative': 0.41425,
#   'fraction_predicted_as_positive': 0.58575,
#   'lift_negative': 1.0853299510509606,
#   'lift_positive': 1.4056492929732365,
#   'matthews_correlation_coefficient': 0.18604847302050895,
#   'model_id': '5c76b6aecb9970013f756c4d',
#   'negative_predictive_value': 0.9447797223898612,
#   'payoff': 13010,
#   'positive_predictive_value': 0.18203158344003414,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10188197179274003,
#   'true_negative_rate': 0.44959793222286043,
#   'true_negative_score': 3131,
#   'true_positive_rate': 0.8233590733590733,
#   'true_positive_score': 853},
#  {'accuracy': 0.5105,
#   'f1_score': 0.29593671341244154,
#   'false_negative_score': 213,
#   'false_positive_rate': 0.5317346352670879,
#   'false_positive_score': 3703,
#   'fraction_predicted_as_negative': 0.43425,
#   'fraction_predicted_as_positive': 0.56575,
#   'lift_negative': 1.078331294721732,
#   'lift_positive': 1.4041565080009624,
#   'matthews_correlation_coefficient': 0.1779272394602058,
#   'model_id': '5c70713ecaf9721bbf6ebea6',
#   'negative_predictive_value': 0.9386873920552677,
#   'payoff': 11310,
#   'positive_predictive_value': 0.1818382677861246,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10319506376981735,
#   'true_negative_rate': 0.46826536473291214,
#   'true_negative_score': 3261,
#   'true_positive_rate': 0.7944015444015444,
#   'true_positive_score': 823},
#  {'accuracy': 0.48575,
#   'f1_score': 0.29117849758787046,
#   'false_negative_score': 191,
#   'false_positive_rate': 0.563325674899483,
#   'false_positive_score': 3923,
#   'fraction_predicted_as_negative': 0.404,
#   'fraction_predicted_as_positive': 0.596,
#   'lift_negative': 1.0808770423280123,
#   'lift_positive': 1.3685185665051438,
#   'matthews_correlation_coefficient': 0.17264035363116845,
#   'model_id': '5c70713ecaf9721bbf6ebea1',
#   'negative_predictive_value': 0.9409034653465347,
#   'payoff': 11310,
#   'positive_predictive_value': 0.17722315436241612,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.09712066501379013,
#   'true_negative_rate': 0.43667432510051696,
#   'true_negative_score': 3041,
#   'true_positive_rate': 0.8156370656370656,
#   'true_positive_score': 845},
#  {'accuracy': 0.535375,
#   'f1_score': 0.3074343208496367,
#   'false_negative_score': 211,
#   'false_positive_rate': 0.503446295232625,
#   'false_positive_score': 3506,
#   'fraction_predicted_as_negative': 0.45862499999999995,
#   'fraction_predicted_as_positive': 0.541375,
#   'lift_negative': 1.0827009098225677,
#   'lift_positive': 1.470943516660441,
#   'matthews_correlation_coefficient': 0.1973511016003154,
#   'model_id': '5c707305caf97224026ebebf',
#   'negative_predictive_value': 0.9424911420005451,
#   'payoff': 13480,
#   'positive_predictive_value': 0.19048718540752713,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10948573990608244,
#   'true_negative_rate': 0.4965537047673751,
#   'true_negative_score': 3458,
#   'true_positive_rate': 0.7963320463320464,
#   'true_positive_score': 825},
#  {'accuracy': 0.445375,
#   'f1_score': 0.28516191396810053,
#   'false_negative_score': 151,
#   'false_positive_rate': 0.6154508902929351,
#   'false_positive_score': 4286,
#   'fraction_predicted_as_negative': 0.35362499999999997,
#   'fraction_predicted_as_positive': 0.646375,
#   'lift_negative': 1.08744887863433,
#   'lift_positive': 1.321596757682621,
#   'matthews_correlation_coefficient': 0.16769995775724433,
#   'model_id': '5c70713ecaf9721bbf6ebeac',
#   'negative_predictive_value': 0.9466242488511841,
#   'payoff': 11680,
#   'positive_predictive_value': 0.17114678011989945,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.09321603577317014,
#   'true_negative_rate': 0.3845491097070649,
#   'true_negative_score': 2678,
#   'true_positive_rate': 0.8542471042471043,
#   'true_positive_score': 885},
#  {'model_id': '5c7070c7caf97217266ebeb0',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'accuracy': 0.47125,
#   'f1_score': 0.29074446680080485,
#   'false_negative_score': 169,
#   'false_positive_rate': 0.5831418724870764,
#   'false_positive_score': 4061,
#   'fraction_predicted_as_negative': 0.384,
#   'fraction_predicted_as_positive': 0.616,
#   'lift_negative': 1.0855680403982386,
#   'lift_positive': 1.35855939427368,
#   'matthews_correlation_coefficient': 0.17516056843473135,
#   'model_id': '5c70727ccaf97222816ebea0',
#   'negative_predictive_value': 0.9449869791666666,
#   'payoff': 12130,
#   'positive_predictive_value': 0.17593344155844157,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.08804436399982676,
#   'true_negative_rate': 0.4168581275129236,
#   'true_negative_score': 2903,
#   'true_positive_rate': 0.8368725868725869,
#   'true_positive_score': 867},
#  {'accuracy': 0.545625,
#   'f1_score': 0.3059003246133282,
#   'false_negative_score': 235,
#   'false_positive_rate': 0.48822515795519816,
#   'false_positive_score': 3400,
#   'fraction_predicted_as_negative': 0.47487500000000005,
#   'fraction_predicted_as_positive': 0.525125,
#   'lift_negative': 1.077704326496029,
#   'lift_positive': 1.4723466282618867,
#   'matthews_correlation_coefficient': 0.19158125331503637,
#   'model_id': '5c70713ecaf9721bbf6ebea7',
#   'negative_predictive_value': 0.9381416162147934,
#   'payoff': 12140,
#   'positive_predictive_value': 0.1906688883599143,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10684517357856342,
#   'true_negative_rate': 0.5117748420448018,
#   'true_negative_score': 3564,
#   'true_positive_rate': 0.7731660231660231,
#   'true_positive_score': 801},
#  {'accuracy': 0.45175,
#   'f1_score': 0.28426892950391647,
#   'false_negative_score': 165,
#   'false_positive_rate': 0.6061171740379092,
#   'false_positive_score': 4221,
#   'fraction_predicted_as_negative': 0.36350000000000005,
#   'fraction_predicted_as_positive': 0.6365,
#   'lift_negative': 1.083584115439039,
#   'lift_positive': 1.3208697419223736,
#   'matthews_correlation_coefficient': 0.16376694889303636,
#   'model_id': '5c70713fcaf9721bbf6ebeb1',
#   'negative_predictive_value': 0.9432599724896836,
#   'payoff': 10930,
#   'positive_predictive_value': 0.17105263157894737,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.08905018121004105,
#   'true_negative_rate': 0.39388282596209073,
#   'true_negative_score': 2743,
#   'true_positive_rate': 0.8407335907335908,
#   'true_positive_score': 871},
#  {'model_id': '5c7070c7caf97217266ebebc',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebecb',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebebf',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c6caf97217266ebe9c',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebec6',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'accuracy': 0.485,
#   'f1_score': 0.2899000344708721,
#   'false_negative_score': 195,
#   'false_positive_rate': 0.5636128661688685,
#   'false_positive_score': 3925,
#   'fraction_predicted_as_negative': 0.40425,
#   'fraction_predicted_as_positive': 0.59575,
#   'lift_negative': 1.0794981665581485,
#   'lift_positive': 1.3626119375175187,
#   'matthews_correlation_coefficient': 0.16978511184653572,
#   'model_id': '5c70713fcaf9721bbf6ebeb3',
#   'negative_predictive_value': 0.9397031539888683,
#   'payoff': 10890,
#   'positive_predictive_value': 0.17645824590851866,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10001761327855394,
#   'true_negative_rate': 0.43638713383113154,
#   'true_negative_score': 3039,
#   'true_positive_rate': 0.8117760617760618,
#   'true_positive_score': 841},
#  {'accuracy': 0.4605,
#   'f1_score': 0.28448275862068967,
#   'false_negative_score': 178,
#   'false_positive_rate': 0.5941987363584147,
#   'false_positive_score': 4138,
#   'fraction_predicted_as_negative': 0.37549999999999994,
#   'fraction_predicted_as_positive': 0.6245,
#   'lift_negative': 1.0806957753437694,
#   'lift_positive': 1.3261574510573708,
#   'matthews_correlation_coefficient': 0.162232944857763,
#   'model_id': '5c70713fcaf9721bbf6ebeb2',
#   'negative_predictive_value': 0.940745672436751,
#   'payoff': 10460,
#   'positive_predictive_value': 0.17173738991192955,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.08630340817693609,
#   'true_negative_rate': 0.4058012636415853,
#   'true_negative_score': 2826,
#   'true_positive_rate': 0.8281853281853282,
#   'true_positive_score': 858},
#  {'model_id': '5c7070c7caf97217266ebeb7',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebec1',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebeb1',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebea1',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebeb6',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebea6',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d9112691',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebeab',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911268a',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d911269f',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebebd',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112685',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126a4',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112667',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d911269a',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911266d',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126ae',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911268b',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911266b',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebebe',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7934d86bd6245333748b2f',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7d82d26bd6240ab8748b51',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911268c',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d9112694',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126bb',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7934d86bd6245333748b2e',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911267f',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126b4',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112680',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126ba',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112675',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d9112693',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70713ecaf9721bbf6ebe9a',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d9112692',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126a9',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'accuracy': 0.24875,
#   'f1_score': 0.24326366154621,
#   'false_negative_score': 70,
#   'false_positive_rate': 0.8529580700746697,
#   'false_positive_score': 5940,
#   'fraction_predicted_as_negative': 0.13675000000000004,
#   'fraction_predicted_as_positive': 0.86325,
#   'lift_negative': 1.0752609135307512,
#   'lift_positive': 1.0801418273181957,
#   'matthews_correlation_coefficient': 0.07766303584068257,
#   'model_id': '5c707304caf97224026ebeab',
#   'negative_predictive_value': 0.9360146252285192,
#   'payoff': 3240,
#   'positive_predictive_value': 0.13987836663770634,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.10400347411632538,
#   'true_negative_rate': 0.14704192992533027,
#   'true_negative_score': 1024,
#   'true_positive_rate': 0.9324324324324325,
#   'true_positive_score': 966},
#  {'model_id': '5c70704580a477d9d91126af',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112666',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'accuracy': 0.22825,
#   'f1_score': 0.23871763255240444,
#   'false_negative_score': 68,
#   'false_positive_rate': 0.8767949454336588,
#   'false_positive_score': 6106,
#   'fraction_predicted_as_negative': 0.11575000000000002,
#   'fraction_predicted_as_positive': 0.88425,
#   'lift_negative': 1.0644065189316732,
#   'lift_positive': 1.0566728123980034,
#   'matthews_correlation_coefficient': 0.06041604558909135,
#   'model_id': '5c707305caf97224026ebeb0',
#   'negative_predictive_value': 0.9265658747300216,
#   'payoff': 1780,
#   'positive_predictive_value': 0.13683912920554142,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.1048373430967331,
#   'true_negative_rate': 0.12320505456634118,
#   'true_negative_score': 858,
#   'true_positive_rate': 0.9343629343629344,
#   'true_positive_score': 968},
#  {'model_id': '5c70704580a477d9d91126c0',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112664',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d9112695',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c6caf97217266ebe98',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126b5',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911266f',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70713ecaf9721bbf6ebe98',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'accuracy': 0.1295,
#   'f1_score': 0.22930500221336875,
#   'false_negative_score': 0,
#   'false_positive_rate': 1.0,
#   'false_positive_score': 6964,
#   'fraction_predicted_as_negative': 0.0,
#   'fraction_predicted_as_positive': 1.0,
#   'lift_negative': 0.0,
#   'lift_positive': 1.0,
#   'matthews_correlation_coefficient': 0.0,
#   'model_id': '5c707305caf97224026ebeba',
#   'negative_predictive_value': 0.0,
#   'payoff': 0,
#   'positive_predictive_value': 0.1295,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.09529250860214233,
#   'true_negative_rate': 0.0,
#   'true_negative_score': 0,
#   'true_positive_rate': 1.0,
#   'true_positive_score': 1036},
#  {'model_id': '5c7070c6caf97217266ebe9b',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112672',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911266a',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c7caf97217266ebec0',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70713ecaf9721bbf6ebe9b',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c7070c6caf97217266ebe9a',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911266c',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70713ecaf9721bbf6ebe99',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'accuracy': 0.1295,
#   'f1_score': 0.22930500221336875,
#   'false_negative_score': 0,
#   'false_positive_rate': 1.0,
#   'false_positive_score': 6964,
#   'fraction_predicted_as_negative': 0.0,
#   'fraction_predicted_as_positive': 1.0,
#   'lift_negative': 0.0,
#   'lift_positive': 1.0,
#   'matthews_correlation_coefficient': 0.0,
#   'model_id': '5c707305caf97224026ebeb5',
#   'negative_predictive_value': 0.0,
#   'payoff': 0,
#   'positive_predictive_value': 0.1295,
#   'project_id': '5c706f7f114a6d305a75e34c',
#   'threshold': 0.12652389705181122,
#   'true_negative_rate': 0.0,
#   'true_negative_score': 0,
#   'true_positive_rate': 1.0,
#   'true_positive_score': 1036},
#  {'model_id': '5c7070c6caf97217266ebe99',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112671',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112674',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112670',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911267a',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112673',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d911266e',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112665',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704580a477d9d91126c1',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112669',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'},
#  {'model_id': '5c70704480a477d9d9112668',
#   'payoff': None,
#   'project_id': '5c706f7f114a6d305a75e34c'}]
