# %%
import pandas as pd
pd.options.display.max_rows = 500
df = pd.read_csv('21-04-12 CFDS accounts.csv')
print(df.shape)
df.head()
# Out:
# (849, 15)
#                     Account Name Advisor Update Due Date  \
# 0    Bank of America Corporation      4/30/2021 10:00 PM
# 1          HONDA MOTOR CO., LTD.      4/23/2021 10:00 PM
# 2                  Nierstichting       4/9/2021 10:00 PM
# 3  JAPAN BUSINESS PRESS CO.,LTD.       4/9/2021 10:00 PM
# 4               KYOTO UNIVERSITY      5/28/2021 10:00 PM
#
#    Days Until Next Advisor Update           Owner Customer Segmentation  \
# 0                            18.0  Glenn Carvajal            High Touch
# 1                            11.0  Kenji Nakamura            High Touch
# 2                            -3.0    Joep Gerrits          Undetermined
# 3                            -3.0  Takeo Masuyama             Low Touch
# 4                            46.0  Takeo Masuyama             Low Touch
#
#    Account Health (CFDS)  Account Relationship Health  Account Usage Health  \
# 0                    3.0                          3.0                   3.0
# ...

# %%
df['Customer Facing Data Scientist'].value_counts()
# Out:
# Yuya Yamamoto           28
# Chad Harness            25
# Bill Surrette           25
# Yusuke Kawagoe          24
# Dave Heinicke           21
# Duncan Renfrow-Symon    21
# Mikio Ogawa             21
# Joseph Blue             20
# Jake Snyder             19
# Yifu Gu                 19
# Yasu Sakamoto           17
# Shinpei Ijichi          16
# Vijay Rajan             16
# Harry Nakayama          16
# Quncai Zou              14
# Matt Cohen              13
# Xavier Fontaine         13
# Mitch Carmen            13
# Aman Sharma             13
# Takafumi Nakano         13
# Andrew Lofgreen         12
# Manik Aggarwal          11
# Isao Sugawara           11
# Javier Lombana          11
# Justin Swansburg        11
# Jesse Wu                11
# Yasunari Niina          10
# Brett Olmstead          10
# Steffen Roecker         10
# Sharath Pareddy         10
# Shel Zaroo               9
# Josh Berry               9
# Rangga Ugahari           9
# Rudy Celekli             8
# ...
