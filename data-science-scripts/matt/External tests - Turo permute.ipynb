# %% [markdown]
# ### For a given project:
# - 1. Upload an external dataset
# - 2. Permute one feature
# - 3. Calculate feature impact

# %%
import pandas as pd
import numpy as np
import os
import datarobot as dr
import time
from pprint import pprint

USERNAME = os.environ['DATAROBOT_USERNAME']
API_TOKEN = os.environ['DATAROBOT_API_TOKEN']
ENDPOINT = 'https://app.datarobot.com/api/v2'

# %%
def establish_dr_client():
    dr.Client(token=API_TOKEN, endpoint=ENDPOINT) 
    
establish_dr_client()

t0 = time.time()

prj = dr.Project.get('602d64004d7845cfbb178a8a') # 10k_diabetes_80
print('project: ', prj)

models = prj.get_models()  # [:12]  # get only the top n to narrow it down
print('%s models' % len(models))

# Load the external dataset
df = pd.read_excel('/Users/matthew.cohen/Documents/DR/Demo/_Diabetes/10k_diabetes_20.xlsx')

# Limit to the top n models
max_models = 3

# Limit columns, or make a subset list
selected_cols = df.columns[:10]

for i, col in enumerate(selected_cols):
    try:
        print('\n**** permuting column \'%s\' (%s of %s) ****\n' % (col, i+1, len(selected_cols)))
        df[col] = np.random.permutation(df[col])

        # Upload the external dataset
        ext_test = prj.upload_dataset(df)
        print('external dataset: %s, id: %s' % (ext_test, ext_test.id))

        # Request n models request/run the external dataset
        print('Request external dataset test for %s models.' % max_models)
        for i, model in enumerate(models):
            if i+1 > max_models:
                break
            model = models[i]
            # print('request model %s %s for external test set' % (i, model))
            model.request_external_test(ext_test.id)

        # Wait for each model to complete scoring the external test set scores before getting the scores
        while len(prj.get_all_jobs()) > 0:
            time.sleep(1)
        print('- Externals test requests complete.')

        # Get the scores for the external dataset for each model
        for i, score in enumerate(dr.ExternalScores.list(prj.id, dataset_id=ext_test.id)):
            cur_model = dr.models.Model.get(project=prj.id, model_id=score.model_id)
            print('model %s: %s, id: %s' % (i, 
                                            cur_model.model_type,
                                            score.model_id)
                 )
            pprint(score.scores)

            while len(prj.get_all_jobs()) > 0:
                time.sleep(1)

        # Delete the external dataset
        print('\ndeleting dataset:', ext_test.id)
        ext_test.delete()
    except ConnectionError as ce:
        print('\n*** Connection error, will re-establish ***')
        print(ce)
    except Exception as e:
        print('\n^^^ Other error ^^^')
        print(e)
establish_dr_client()
        
print('\nDone.  Time: %d.03 minutes' % ((time.time() - t0)/60))
# Out:
# project:  Project(10k_diabetes_80.xlsx)
# 35 models
#
# **** permuting column 'race' (1 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a81565aa2741f1d5169684
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.71483},
#  {'label': 'Area Under PR Curve', 'value': 0.61898},
#  {'label': 'FVE Binomial', 'value': 0.1103},
#  {'label': 'Gini Norm', 'value': 0.42966},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.31103},
#  {'label': 'LogLoss', 'value': 0.59749},
#  {'label': 'Max MCC', 'value': 0.30817},
#  {'label': 'RMSE', 'value': 0.45448},
#  {'label': 'Rate@Top10%', 'value': 0.725},
#  {'label': 'Rate@Top5%', 'value': 0.8},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.7118},
#  {'label': 'Area Under PR Curve', 'value': 0.60516},
#  {'label': 'FVE Binomial', 'value': 0.099},
#  {'label': 'Gini Norm', 'value': 0.4236},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.31617},
#  {'label': 'LogLoss', 'value': 0.60508},
#  {'label': 'Max MCC', 'value': 0.30932},
#  {'label': 'RMSE', 'value': 0.45739},
#  {'label': 'Rate@Top10%', 'value': 0.72},
#  {'label': 'Rate@Top5%', 'value': 0.72},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.71203},
#  {'label': 'Area Under PR Curve', 'value': 0.6105},
#  {'label': 'FVE Binomial', 'value': 0.10527},
#  {'label': 'Gini Norm', 'value': 0.42406},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.31926},
#  {'label': 'LogLoss', 'value': 0.60087},
#  {'label': 'Max MCC', 'value': 0.3125},
#  {'label': 'RMSE', 'value': 0.45571},
#  {'label': 'Rate@Top10%', 'value': 0.715},
#  {'label': 'Rate@Top5%', 'value': 0.78},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
#
# deleting dataset: 60a81565aa2741f1d5169684
#
# **** permuting column 'gender' (2 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a815cad5790f23f11696e0
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.71317},
#  {'label': 'Area Under PR Curve', 'value': 0.61777},
#  {'label': 'FVE Binomial', 'value': 0.10913},
#  {'label': 'Gini Norm', 'value': 0.42634},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.30325},
#  {'label': 'LogLoss', 'value': 0.59828},
#  {'label': 'Max MCC', 'value': 0.30474},
#  {'label': 'RMSE', 'value': 0.45489},
#  {'label': 'Rate@Top10%', 'value': 0.72},
#  {'label': 'Rate@Top5%', 'value': 0.8},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.70981},
#  {'label': 'Area Under PR Curve', 'value': 0.60288},
#  {'label': 'FVE Binomial', 'value': 0.09773},
#  {'label': 'Gini Norm', 'value': 0.41962},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.30911},
#  {'label': 'LogLoss', 'value': 0.60594},
#  {'label': 'Max MCC', 'value': 0.3031},
#  {'label': 'RMSE', 'value': 0.45785},
#  {'label': 'Rate@Top10%', 'value': 0.695},
#  {'label': 'Rate@Top5%', 'value': 0.75},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.71177},
#  {'label': 'Area Under PR Curve', 'value': 0.6093},
#  {'label': 'FVE Binomial', 'value': 0.10497},
#  {'label': 'Gini Norm', 'value': 0.42354},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.31173},
#  {'label': 'LogLoss', 'value': 0.60107},
#  {'label': 'Max MCC', 'value': 0.30596},
#  {'label': 'RMSE', 'value': 0.45583},
#  {'label': 'Rate@Top10%', 'value': 0.715},
#  {'label': 'Rate@Top5%', 'value': 0.78},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
#
# deleting dataset: 60a815cad5790f23f11696e0
#
# **** permuting column 'age' (3 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a8163688ba99190d56786b
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.70589},
#  {'label': 'Area Under PR Curve', 'value': 0.61053},
#  {'label': 'FVE Binomial', 'value': 0.1029},
#  {'label': 'Gini Norm', 'value': 0.41178},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.29066},
#  {'label': 'LogLoss', 'value': 0.60246},
#  {'label': 'Max MCC', 'value': 0.29162},
#  {'label': 'RMSE', 'value': 0.45684},
#  {'label': 'Rate@Top10%', 'value': 0.715},
#  {'label': 'Rate@Top5%', 'value': 0.8},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.70588},
#  {'label': 'Area Under PR Curve', 'value': 0.60375},
#  {'label': 'FVE Binomial', 'value': 0.10007},
#  {'label': 'Gini Norm', 'value': 0.41176},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.30215},
#  {'label': 'LogLoss', 'value': 0.60436},
#  {'label': 'Max MCC', 'value': 0.29572},
#  {'label': 'RMSE', 'value': 0.45737},
#  {'label': 'Rate@Top10%', 'value': 0.71},
#  {'label': 'Rate@Top5%', 'value': 0.77},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.7049},
#  {'label': 'Area Under PR Curve', 'value': 0.59884},
#  {'label': 'FVE Binomial', 'value': 0.09404},
#  {'label': 'Gini Norm', 'value': 0.4098},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.29789},
#  {'label': 'LogLoss', 'value': 0.60841},
#  {'label': 'Max MCC', 'value': 0.29557},
#  {'label': 'RMSE', 'value': 0.45898},
#  {'label': 'Rate@Top10%', 'value': 0.69},
#  {'label': 'Rate@Top5%', 'value': 0.72},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
#
# deleting dataset: 60a8163688ba99190d56786b
#
# **** permuting column 'weight' (4 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a816aace0e3d5016f9709d
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.69921},
#  {'label': 'Area Under PR Curve', 'value': 0.60464},
#  {'label': 'FVE Binomial', 'value': 0.0975},
#  {'label': 'Gini Norm', 'value': 0.39842},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.27981},
#  {'label': 'LogLoss', 'value': 0.60609},
#  {'label': 'Max MCC', 'value': 0.27415},
#  {'label': 'RMSE', 'value': 0.45868},
#  {'label': 'Rate@Top10%', 'value': 0.71},
#  {'label': 'Rate@Top5%', 'value': 0.83},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.69909},
#  {'label': 'Area Under PR Curve', 'value': 0.59689},
#  {'label': 'FVE Binomial', 'value': 0.09426},
#  {'label': 'Gini Norm', 'value': 0.39818},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.29441},
#  {'label': 'LogLoss', 'value': 0.60826},
#  {'label': 'Max MCC', 'value': 0.28803},
#  {'label': 'RMSE', 'value': 0.45936},
#  {'label': 'Rate@Top10%', 'value': 0.71},
#  {'label': 'Rate@Top5%', 'value': 0.78},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.69734},
#  {'label': 'Area Under PR Curve', 'value': 0.5921},
#  {'label': 'FVE Binomial', 'value': 0.0889},
#  {'label': 'Gini Norm', 'value': 0.39468},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.28188},
#  {'label': 'LogLoss', 'value': 0.61186},
#  {'label': 'Max MCC', 'value': 0.27754},
#  {'label': 'RMSE', 'value': 0.46076},
#  {'label': 'Rate@Top10%', 'value': 0.715},
#  {'label': 'Rate@Top5%', 'value': 0.72},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
#
# deleting dataset: 60a816aace0e3d5016f9709d
#
# **** permuting column 'admission_type_id' (5 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a8170d9f850485eb5677fd
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.69472},
#  {'label': 'Area Under PR Curve', 'value': 0.59625},
#  {'label': 'FVE Binomial', 'value': 0.09288},
#  {'label': 'Gini Norm', 'value': 0.38944},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.27102},
#  {'label': 'LogLoss', 'value': 0.60919},
#  {'label': 'Max MCC', 'value': 0.27238},
#  {'label': 'RMSE', 'value': 0.4602},
#  {'label': 'Rate@Top10%', 'value': 0.715},
#  {'label': 'Rate@Top5%', 'value': 0.81},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.6913},
#  {'label': 'Area Under PR Curve', 'value': 0.58402},
#  {'label': 'FVE Binomial', 'value': 0.08647},
#  {'label': 'Gini Norm', 'value': 0.3826},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.28536},
#  {'label': 'LogLoss', 'value': 0.61349},
#  {'label': 'Max MCC', 'value': 0.27938},
#  {'label': 'RMSE', 'value': 0.46188},
#  {'label': 'Rate@Top10%', 'value': 0.71},
#  {'label': 'Rate@Top5%', 'value': 0.75},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.69359},
#  {'label': 'Area Under PR Curve', 'value': 0.58714},
#  {'label': 'FVE Binomial', 'value': 0.08539},
#  {'label': 'Gini Norm', 'value': 0.38718},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.28609},
#  {'label': 'LogLoss', 'value': 0.61422},
#  {'label': 'Max MCC', 'value': 0.28348},
#  {'label': 'RMSE', 'value': 0.46187},
#  {'label': 'Rate@Top10%', 'value': 0.71},
#  {'label': 'Rate@Top5%', 'value': 0.73},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
#
# deleting dataset: 60a8170d9f850485eb5677fd
#
# **** permuting column 'discharge_disposition_id' (6 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a817769c55174bd5f97142
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.66612},
#  {'label': 'Area Under PR Curve', 'value': 0.5564},
#  {'label': 'FVE Binomial', 'value': 0.05789},
#  {'label': 'Gini Norm', 'value': 0.33224},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.25565},
#  {'label': 'LogLoss', 'value': 0.63269},
#  {'label': 'Max MCC', 'value': 0.25038},
#  {'label': 'RMSE', 'value': 0.46964},
#  {'label': 'Rate@Top10%', 'value': 0.67},
#  {'label': 'Rate@Top5%', 'value': 0.7},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.66812},
#  {'label': 'Area Under PR Curve', 'value': 0.55672},
#  {'label': 'FVE Binomial', 'value': 0.06117},
#  {'label': 'Gini Norm', 'value': 0.33624},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.26174},
#  {'label': 'LogLoss', 'value': 0.63049},
#  {'label': 'Max MCC', 'value': 0.25806},
#  {'label': 'RMSE', 'value': 0.46898},
#  {'label': 'Rate@Top10%', 'value': 0.645},
#  {'label': 'Rate@Top5%', 'value': 0.74},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.66896},
#  {'label': 'Area Under PR Curve', 'value': 0.56623},
#  {'label': 'FVE Binomial', 'value': 0.06271},
#  {'label': 'Gini Norm', 'value': 0.33792},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.25405},
#  {'label': 'LogLoss', 'value': 0.62945},
#  {'label': 'Max MCC', 'value': 0.25684},
#  {'label': 'RMSE', 'value': 0.46833},
#  {'label': 'Rate@Top10%', 'value': 0.715},
#  {'label': 'Rate@Top5%', 'value': 0.77},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
#
# deleting dataset: 60a817769c55174bd5f97142
#
# **** permuting column 'admission_source_id' (7 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a817d270fc0d7fbff970a1
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.65175},
#  {'label': 'Area Under PR Curve', 'value': 0.55183},
#  {'label': 'FVE Binomial', 'value': 0.0489},
#  {'label': 'Gini Norm', 'value': 0.3035},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.22681},
#  {'label': 'LogLoss', 'value': 0.63873},
#  {'label': 'Max MCC', 'value': 0.22575},
#  {'label': 'RMSE', 'value': 0.47258},
#  {'label': 'Rate@Top10%', 'value': 0.69},
#  {'label': 'Rate@Top5%', 'value': 0.74},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.65089},
#  {'label': 'Area Under PR Curve', 'value': 0.54655},
#  {'label': 'FVE Binomial', 'value': 0.05072},
#  {'label': 'Gini Norm', 'value': 0.30178},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.22943},
#  {'label': 'LogLoss', 'value': 0.6375},
#  {'label': 'Max MCC', 'value': 0.23478},
#  {'label': 'RMSE', 'value': 0.47228},
#  {'label': 'Rate@Top10%', 'value': 0.635},
#  {'label': 'Rate@Top5%', 'value': 0.73},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.65273},
#  {'label': 'Area Under PR Curve', 'value': 0.54812},
#  {'label': 'FVE Binomial', 'value': 0.04852},
#  {'label': 'Gini Norm', 'value': 0.30546},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.22829},
#  {'label': 'LogLoss', 'value': 0.63898},
#  {'label': 'Max MCC', 'value': 0.22531},
#  {'label': 'RMSE', 'value': 0.47252},
#  {'label': 'Rate@Top10%', 'value': 0.66},
#  {'label': 'Rate@Top5%', 'value': 0.69},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
#
# deleting dataset: 60a817d270fc0d7fbff970a1
#
# **** permuting column 'time_in_hospital' (8 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a81835c35da15972169770
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.64758},
#  {'label': 'Area Under PR Curve', 'value': 0.54998},
#  {'label': 'FVE Binomial', 'value': 0.04601},
#  {'label': 'Gini Norm', 'value': 0.29516},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.22478},
#  {'label': 'LogLoss', 'value': 0.64067},
#  {'label': 'Max MCC', 'value': 0.22315},
#  {'label': 'RMSE', 'value': 0.47348},
#  {'label': 'Rate@Top10%', 'value': 0.685},
#  {'label': 'Rate@Top5%', 'value': 0.76},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.64691},
#  {'label': 'Area Under PR Curve', 'value': 0.54351},
#  {'label': 'FVE Binomial', 'value': 0.04419},
#  {'label': 'Gini Norm', 'value': 0.29382},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.21632},
#  {'label': 'LogLoss', 'value': 0.64189},
#  {'label': 'Max MCC', 'value': 0.2132},
#  {'label': 'RMSE', 'value': 0.47386},
#  {'label': 'Rate@Top10%', 'value': 0.655},
#  {'label': 'Rate@Top5%', 'value': 0.68},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.64345},
#  {'label': 'Area Under PR Curve', 'value': 0.53918},
#  {'label': 'FVE Binomial', 'value': 0.04483},
#  {'label': 'Gini Norm', 'value': 0.2869},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.22008},
#  {'label': 'LogLoss', 'value': 0.64146},
#  {'label': 'Max MCC', 'value': 0.22296},
#  {'label': 'RMSE', 'value': 0.47407},
#  {'label': 'Rate@Top10%', 'value': 0.645},
#  {'label': 'Rate@Top5%', 'value': 0.7},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
#
# deleting dataset: 60a81835c35da15972169770
#
# **** permuting column 'payer_code' (9 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a81895ecfd802cfcf97183
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.64412},
#  {'label': 'Area Under PR Curve', 'value': 0.54959},
#  {'label': 'FVE Binomial', 'value': 0.04372},
#  {'label': 'Gini Norm', 'value': 0.28824},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.2156},
#  {'label': 'LogLoss', 'value': 0.64221},
#  {'label': 'Max MCC', 'value': 0.2149},
#  {'label': 'RMSE', 'value': 0.47408},
#  {'label': 'Rate@Top10%', 'value': 0.685},
#  {'label': 'Rate@Top5%', 'value': 0.72},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.64233},
#  {'label': 'Area Under PR Curve', 'value': 0.53963},
#  {'label': 'FVE Binomial', 'value': 0.04049},
#  {'label': 'Gini Norm', 'value': 0.28466},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.20871},
#  {'label': 'LogLoss', 'value': 0.64437},
#  {'label': 'Max MCC', 'value': 0.21042},
#  {'label': 'RMSE', 'value': 0.47494},
#  {'label': 'Rate@Top10%', 'value': 0.655},
#  {'label': 'Rate@Top5%', 'value': 0.68},
#  {'label': 'Rate@TopTenth%', 'value': 0.5}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.64009},
#  {'label': 'Area Under PR Curve', 'value': 0.53724},
#  {'label': 'FVE Binomial', 'value': 0.04273},
#  {'label': 'Gini Norm', 'value': 0.28018},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.21565},
#  {'label': 'LogLoss', 'value': 0.64287},
#  {'label': 'Max MCC', 'value': 0.2118},
#  {'label': 'RMSE', 'value': 0.47468},
#  {'label': 'Rate@Top10%', 'value': 0.65},
#  {'label': 'Rate@Top5%', 'value': 0.67},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
#
# deleting dataset: 60a81895ecfd802cfcf97183
#
# **** permuting column 'medical_specialty' (10 of 10) ****
#
# external dataset: PredictionDataset('predict.csv'), id: 60a81908c0d6777501f9701c
# Request external dataset test for 3 models.
# - Externals test requests complete.
# model 0: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6718bc10c707f16bc0c1
# [{'label': 'AUC', 'value': 0.62788},
#  {'label': 'Area Under PR Curve', 'value': 0.53905},
#  {'label': 'FVE Binomial', 'value': 0.03122},
#  {'label': 'Gini Norm', 'value': 0.25576},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.19763},
#  {'label': 'LogLoss', 'value': 0.6506},
#  {'label': 'Max MCC', 'value': 0.19553},
#  {'label': 'RMSE', 'value': 0.47796},
#  {'label': 'Rate@Top10%', 'value': 0.66},
#  {'label': 'Rate@Top5%', 'value': 0.7},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 1: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d64db1be244c02d7bd243
# [{'label': 'AUC', 'value': 0.61969},
#  {'label': 'Area Under PR Curve', 'value': 0.52188},
#  {'label': 'FVE Binomial', 'value': 0.02992},
#  {'label': 'Gini Norm', 'value': 0.23938},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.17872},
#  {'label': 'LogLoss', 'value': 0.65147},
#  {'label': 'Max MCC', 'value': 0.19091},
#  {'label': 'RMSE', 'value': 0.47892},
#  {'label': 'Rate@Top10%', 'value': 0.615},
#  {'label': 'Rate@Top5%', 'value': 0.66},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
# model 2: Light Gradient Boosted Trees Classifier with Early Stopping, id: 602d6671406e5972767bd275
# [{'label': 'AUC', 'value': 0.6221},
#  {'label': 'Area Under PR Curve', 'value': 0.52328},
#  {'label': 'FVE Binomial', 'value': 0.02567},
#  {'label': 'Gini Norm', 'value': 0.2442},
#  {'label': 'Kolmogorov-Smirnov', 'value': 0.1836},
#  {'label': 'LogLoss', 'value': 0.65433},
#  {'label': 'Max MCC', 'value': 0.19238},
#  {'label': 'RMSE', 'value': 0.47966},
#  {'label': 'Rate@Top10%', 'value': 0.6},
#  {'label': 'Rate@Top5%', 'value': 0.65},
#  {'label': 'Rate@TopTenth%', 'value': 1.0}]
#
# deleting dataset: 60a81908c0d6777501f9701c
# Time: 17.03 minutes
